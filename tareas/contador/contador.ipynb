# %%
# python notebook for Make Your Own Neural Network
# code for a 3-layer neural network, and code for learning the MNIST dataset
# (c) Tariq Rashid, 2016
# license is GPLv2

# %%
import numpy
# scipy.special for the sigmoid function expit()
import scipy.special
# library for plotting arrays
import matplotlib.pyplot
# ensure the plots are inside this notebook, not an external window
# %matplotlib inline

# %%
# neural network class definition
class neuralNetwork:
    
    
    # initialise the neural network
    def __init__(self, inputnodes, hiddennodes, outputnodes, learningrate):
        # set number of nodes in each input, hidden, output layer
        self.inodes = inputnodes
        self.hnodes = hiddennodes
        self.onodes = outputnodes
        
        # link weight matrices, wih and who
        # weights inside the arrays are w_i_j, where link is from node i to node j in the next layer
        # w11 w21
        # w12 w22 etc 
        self.wih = numpy.random.normal(0.0, pow(self.inodes, -0.5), (self.hnodes, self.inodes))
        #self.wih = numpy.random.normal(0.0, 0.5, (self.hnodes, self.inodes))
        self.who = numpy.random.normal(0.0, pow(self.hnodes, -0.5), (self.onodes, self.hnodes))
        #self.who = numpy.random.normal(0.0, 0.5, (self.hnodes, self.inodes))
        print("wih: ", self.wih)
        print("who: ", self.who)

        # learning rate
        self.lr = learningrate
        
        # activation function is the sigmoid function
        self.activation_function = lambda x: scipy.special.expit(x)
        
        pass

    
    # train the neural network
    def train(self, inputs_list, targets_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        print("INPUTS")
        print(inputs)
        print("===========================")
        targets = numpy.array(targets_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        print("HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)")
        print(hidden_inputs)
        print("===========================")
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        print("HIDDEN OUTPUTS (después de aplicar la función sigmoide)")
        print(hidden_outputs)
        print("===========================")
        
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        print("FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)")
        print(final_inputs)
        print("===========================")
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        print("FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)")
        print(final_outputs)
        print("===========================")
        
        # output layer error is the (target - actual)
        output_errors = targets - final_outputs
        print("ERROR (target - valor de los final outputs)")
        print(output_errors)
        print("===========================")
        # hidden layer error is the output_errors, split by weights, recombined at hidden nodes
        hidden_errors = numpy.dot(self.who.T, output_errors) 
        
        # update the weights for the links between the hidden and output layers
        print("Peso actualizado del output layer: ", self.who)
        self.who += self.lr * numpy.dot((output_errors * final_outputs * (1.0 - final_outputs)), numpy.transpose(hidden_outputs))
        
        # update the weights for the links between the input and hidden layers
        self.wih += self.lr * numpy.dot((hidden_errors * hidden_outputs * (1.0 - hidden_outputs)), numpy.transpose(inputs))
        print("Peso actualizado del hidden layer: ", self.wih)
        
        print("============= FINAL DE FASE DE ENTRENAMIENTO ==============")
        
        pass

    
    # query the neural network
    def query(self, inputs_list):
        # convert inputs list to 2d array
        inputs = numpy.array(inputs_list, ndmin=2).T
        
        # calculate signals into hidden layer
        hidden_inputs = numpy.dot(self.wih, inputs)
        # calculate the signals emerging from hidden layer
        hidden_outputs = self.activation_function(hidden_inputs)
        
        # calculate signals into final output layer
        final_inputs = numpy.dot(self.who, hidden_outputs)
        # calculate the signals emerging from final output layer
        final_outputs = self.activation_function(final_inputs)
        
        return final_outputs

# %%
# number of input, hidden and output nodes
input_nodes = 3
hidden_nodes = 3
output_nodes = 3

# learning rate
learning_rate = 0.1

# create instance of neural network
n = neuralNetwork(input_nodes,hidden_nodes,output_nodes, learning_rate)
# Out:
# wih:  [[ 1.14141141 -0.16091703 -0.21066219]
#  [ 0.34570386 -0.50197504 -0.76776826]
#  [ 0.45400492 -0.63124494 -0.0612365 ]]
# who:  [[-0.79266863  0.69793782 -0.69002279]
#  [ 1.2414637   0.1591999  -0.72928726]
#  [ 0.07503579  0.65811911  0.70649624]]

# %%
# load the mnist training data CSV file into a list
training_data_file = open("mnist_dataset/contador.csv", 'r')
training_data_list = training_data_file.readlines()
training_data_file.close()

# %%
# load the mnist test data CSV file into a list
test_data_file = open("mnist_dataset/contador.csv", 'r')
test_data_list = test_data_file.readlines()
test_data_file.close()

# %%
# train the neural network

# epochs is the number of times the training data set is used for training
epochs = 100

for e in range(epochs):
    # go through all records in the training data set
    contador = 1
    for record in training_data_list:
        print("Iteración #", e)
        # split the record by the ',' commas
        all_values = record.split(',')
        # scale and shift the inputs
        inputs = (numpy.asfarray(all_values[0:3]) / 1.0) + 0.00
        # inputs = (numpy.asfarray(all_values[0:3]) / 255.0 * 0.99) + 0.01
        # create the target output values (all 0.01, except the desired label which is 0.99)
        # targets = numpy.zeros(output_nodes) + 0.01
        target_values = training_data_list[contador].split(',')
        targets = (numpy.asfarray(target_values[0:3]) / 1.0) + 0.00
        print("inputs -> ", inputs)
        print("targets -> ", targets)
        # all_values[0] is the target label for this record
        # targets[int(all_values[0])] = 0.99
        n.train(inputs, targets)
        contador += 1
        if(contador == 8):
            contador = 0
        pass
    pass
# Out:
# Iteración # 0
# inputs ->  [ 0.  0.  0.]
# targets ->  [ 0.  0.  1.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.5]
#  [ 0.5]
#  [ 0.5]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.2204458 ]
#  [ 0.20875223]
#  [ 0.60981967]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.44511065]
#  [ 0.55199936]
#  [ 0.64789967]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.44511065]
#  [-0.55199936]
#  [ 0.35210033]]
# ===========================
# Peso actualizado del output layer:  [[-0.63942945  0.79153979 -0.59300195]
#  [ 1.13921314  0.08284051 -0.8045492 ]
#  [-0.04183664  0.64304896  0.61842702]]
# Peso actualizado del hidden layer:  [[ 0.80433151 -0.32413786 -0.38132968]
#  [ 0.52644112 -0.48863392 -1.04133773]
#  [ 0.20912129 -0.68426032 -0.46084862]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 0
# inputs ->  [ 0.  0.  1.]
# targets ->  [ 0.  1.  0.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.38132968]
#  [-1.04133773]
#  [-0.46084862]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.40580624]
#  [ 0.26089196]
#  [ 0.38678453]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.28813288]
#  [ 0.16553464]
#  [ 0.39421769]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.42846103]
#  [ 0.54128942]
#  [ 0.59729761]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.42846103]
#  [ 0.45871058]
#  [-0.59729761]]
# ===========================
# Peso actualizado del output layer:  [[-0.64492628  0.78604296 -0.59849878]
#  [ 1.13238778  0.07601515 -0.81137457]
#  [-0.03782048  0.64706511  0.62244318]]
# Peso actualizado del hidden layer:  [[ 0.80433151 -0.32413786 -0.36159691]
#  [ 0.52644112 -0.48863392 -1.05461216]
#  [ 0.20912129 -0.68426032 -0.47241212]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 0
# inputs ->  [ 0.  1.  0.]
# targets ->  [ 0.  1.  1.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.32413786]
#  [-0.48863392]
#  [-0.68426032]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.41966765]
#  [ 0.38021543]
#  [ 0.33531111]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.17666074]
#  [ 0.23661237]
#  [ 0.43312903]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45594932]
#  [ 0.55887865]
#  [ 0.6066206 ]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.45594932]
#  [ 0.44112135]
#  [ 0.3933794 ]]
# ===========================
# Peso actualizado del output layer:  [[-0.6491841   0.78330562 -0.60255702]
#  [ 1.13700973  0.07898659 -0.80696926]
#  [-0.04365069  0.64331688  0.61688625]]
# Peso actualizado del hidden layer:  [[ 0.80433151 -0.30513188 -0.36159691]
#  [ 0.52644112 -0.49026551 -1.05461216]
#  [ 0.20912129 -0.68066231 -0.47241212]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 0
# inputs ->  [ 0.  1.  1.]
# targets ->  [ 1.  0.  0.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0
]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 2
# inputs ->  [ 0.  0.  0.]
# targets ->  [ 0.  0.  1.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.5]
#  [ 0.5]
#  [ 0.5]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.19579046]
#  [ 0.18887321]
#  [ 0.59859819]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45120815]
#  [ 0.54707843]
#  [ 0.64533553]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.45120815]
#  [-0.54707843]
#  [ 0.35466447]]
# ===========================
# Peso actualizado del output layer:  [[-0.61784723  0.80741311 -0.58114679]
#  [ 1.12377583  0.06999492 -0.81602432]
#  [-0.05817067  0.64545547  0.60991159]]
# Peso actualizado del hidden layer:  [[ 0.75010498 -0.34423888 -0.39798684]
#  [ 0.56346505 -0.48698849 -1.09376764]
#  [ 0.16897582 -0.690621   -0.52997582]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 2
# inputs ->  [ 0.  0.  1.]
# targets ->  [ 0.  1.  0.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.39798684]
#  [-1.09376764]
#  [-0.52997582]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.40179612]
#  [ 0.25090947]
#  [ 0.37052253]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.26670516]
#  [ 0.15980047]
#  [ 0.36871714]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.43371615]
#  [ 0.53986532]
#  [ 0.59114896]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.43371615]
#  [ 0.46013468]
#  [-0.59114896]]
# ===========================
# Peso actualizado del output layer:  [[-0.62343363  0.80182672 -0.58673318]
#  [ 1.11699798  0.06321707 -0.82280218]
#  [-0.05411194  0.64951421  0.61397033]]
# Peso actualizado del hidden layer:  [[ 0.75010498 -0.34423888 -0.37836535]
#  [ 0.56346505 -0.48698849 -1.10697397]
#  [ 0.16897582 -0.690621   -0.54133608]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 2
# inputs ->  [ 0.  1.  0.]
# targets ->  [ 0.  1.  1.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.34423888]
#  [-0.48698849]
#  [-0.690621  ]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.41478017]
#  [ 0.38060326]
#  [ 0.33389494]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.15342771]
#  [ 0.21705033]
#  [ 0.42425111]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.46171814]
#  [ 0.55405055]
#  [ 0.60450005]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.46171814]
#  [ 0.44594945]
#  [ 0.39549995]]
# ===========================
# Peso actualizado del output layer:  [[-0.6277137   0.79915394 -0.59068012]
#  [ 1.1215906   0.06608502 -0.81856702]
#  [-0.05985263  0.64592931  0.60867645]]
# Peso actualizado del hidden layer:  [[ 0.75010498 -0.32563723 -0.37836535]
#  [ 0.56346505 -0.48896988 -1.10697397]
#  [ 0.16897582 -0.68732001 -0.54133608]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 2
# inputs ->  [ 0.  1.  1.]
# targets ->  [ 1.  0.  0.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.70400258]
#  [-1.59594385]
#  [-1.22865609]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.3309254 ]
#  [ 0.16854928]
#  [ 0.22641673]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.20994823]
#  [ 0.20001637]
#  [ 0.229498  ]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.44770489]
#  [ 0.54983805]
#  [ 0.557124  ]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.55229511]
#  [-0.54983805]
#  [-0.557124  ]]
# ===========================
# Peso actualizado del output layer:  [[-0.63247342  0.79478641 -0.59451166]
#  [ 1.12616084  0.07027868 -0.81488801]
#  [-0.05593064  0.64952815  0.61183363]]
# Peso actualizado del hidden layer:  [[ 0.75010498 -0.34639162 -0.39911975]
#  [ 0.56346505 -0.48843108 -1.10643517]
#  [ 0.16897582 -0.69119362 -0.54520968]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 2
# inputs ->  [ 1.  0.  0.]
# targets ->  [ 1.  0.  1.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0
]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 0.  0.  1.]
# targets ->  [ 0.  1.  0.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.410532  ]
#  [-1.1458626 ]
#  [-0.59643594]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.39878456]
#  [ 0.24124561]
#  [ 0.35515952]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.24881718]
#  [ 0.15606422]
#  [ 0.3459919 ]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.43811465]
#  [ 0.53893706]
#  [ 0.58564529]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.43811465]
#  [ 0.46106294]
#  [-0.58564529]]
# ===========================
# Peso actualizado del output layer:  [[-0.60430446  0.81686698 -0.57691107]
#  [ 1.10277137  0.05105225 -0.83348494]
#  [-0.06894453  0.6533986   0.60777301]]
# Peso actualizado del hidden layer:  [[ 0.69942471 -0.36137374 -0.39102601]
#  [ 0.60028193 -0.48592462 -1.15898707]
#  [ 0.13104658 -0.69662126 -0.60760015]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 0.  1.  0.]
# targets ->  [ 0.  1.  1.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.36137374]
#  [-0.48592462]
#  [-0.69662126]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.41062706]
#  [ 0.38085409]
#  [ 0.33256176]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.13292605]
#  [ 0.19936787]
#  [ 0.41734963]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.46681733]
#  [ 0.54967753]
#  [ 0.60284887]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.46681733]
#  [ 0.45032247]
#  [ 0.39715113]]
# ===========================
# Peso actualizado del output layer:  [[-0.60860538  0.81426513 -0.58074149]
#  [ 1.10734012  0.05381612 -0.82941599]
#  [-0.07461187  0.64997013  0.60272564]]
# Peso actualizado del hidden layer:  [[ 0.69942471 -0.34314692 -0.39102601]
#  [ 0.60028193 -0.48822942 -1.15898707]
#  [ 0.13104658 -0.69358104 -0.60760015]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 0.  1.  1.]
# targets ->  [ 1.  0.  0.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.73417293]
#  [-1.64721649]
#  [-1.3011812 ]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.32427968]
#  [ 0.1614855 ]
#  [ 0.21396629]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.19321398]
#  [ 0.1932744 ]
#  [ 0.21225618]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45184622]
#  [ 0.54816875]
#  [ 0.55286572]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.54815378]
#  [-0.54816875]
#  [-0.55286572]]
# ===========================
# Peso actualizado del output layer:  [[-0.61337647  0.80983997 -0.58460554]
#  [ 1.11191735  0.05806147 -0.82570895]
#  [-0.07070735  0.65359154  0.60588786]]
# Peso actualizado del hidden layer:  [[ 0.69942471 -0.36301368 -0.41089277]
#  [ 0.60028193 -0.48754235 -1.15829999]
#  [ 0.13104658 -0.69699184 -0.61101095]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 1.  0.  0.]
# targets ->  [ 1.  0.  1.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.69942471]
#  [ 0.60028193]
#  [ 0.13104658]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.66806021]
#  [ 0.6457208 ]
#  [ 0.53271484]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.19236547]
#  [ 0.33454723]
#  [ 0.69162256]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45205638]
#  [ 0.58286538]
#  [ 0.66632778]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.54794362]
#  [-0.58286538]
#  [ 0.33367222]]
# ===========================
# Peso actualizado del output layer:  [[-0.60897381  0.81203242 -0.58170057]
#  [ 1.10751459  0.05586898 -0.82861398]
#  [-0.07513933  0.6513845   0.60296356]]
# Peso actualizado del hidden layer:  [[ 0.67715407 -0.36301368 -0.41089277]
#  [ 0.61468804 -0.48754235 -1.15829999]
#  [ 0.14014306 -0.69699184 -0.61101095]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 1.  0.  1.]
# targets ->  [ 1.  1.  0.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.2662613 ]
#  [-0.54361195]
#  [-0.47086789]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.56617483]
#  [ 0.36734775]
#  [ 0.38441085]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.25896676]
#  [ 0.3174183 ]
#  [ 0.43461337]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.43561772]
#  [ 0.57869494]
#  [ 0.60697476]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.56438228]
#  [ 0.42130506]
#  [-0.60697476]]
# ===========================
# Peso actualizado del output layer:  [[-0.59990647  0.82079655 -0.57447022]
#  [ 1.09804724  0.04671821 -0.83616329]
#  [-0.07018319  0.65617491  0.60691561]]
# Peso actualizado del hidden layer:  [[ 0.68124699 -0.36301368 -0.40679984]
#  [ 0.6166552  -0.48754235 -1.15633284]
#  [ 0.11541704 -0.69699184 -0.63573697]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 1.  1.  0.]
# targets ->  [ 1.  1.  1.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.31823331]
#  [ 0.12911285]
#  [-0.5815748 ]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.57889364]
#  [ 0.53223345]
#  [ 0.35857031]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.10724134]
#  [ 0.36748494]
#  [ 0.51665886]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.47321533]
#  [ 0.59085111]
#  [ 0.62636616]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.52678467]
#  [ 0.40914889]
#  [ 0.37363384]]
# ===========================
# Peso actualizado del output layer:  [[-0.59205044  0.82589373 -0.56913629]
#  [ 1.10386283  0.05049151 -0.83221473]
#  [-0.07838127  0.6508558   0.60134943]]
# Peso actualizado del hidden layer:  [[ 0.68394011 -0.36032056 -0.40679984]
#  [ 0.63405529 -0.47014225 -1.15633284]
#  [ 0.1058577  -0.70655117 -0.63573697]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 4
# inputs ->  [ 1.  1.  1.]
# targets ->  [ 0.  0.  0.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.0831803 ]
#  [-0.9924198 ]
#  [-1.23643044]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.47921691]
#  [ 0.27043439]
#  [ 0.22505793]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.18186633]
#  [ 0.36031362]
#  [ 0.27818064]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45465832]
#  [ 0.58911635]
#  [ 0.56910013]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.45465832]
#  [-0.58911635]
#  [-0.56910013]]
# ===========================
# Peso actualizado del output layer:  [[-0.58444851  0.83288293 -0.5644276 ]
#  [ 1.10958867  0.05575583 -0.82866811]
#  [-0.0733193   0.65550976  0.60448484]]
# Peso actualizado del hidden layer:  [[ 0.6752994  -0.36896126 -0.41544055]
#  [ 0.61857567 -0.48562188 -1.17181246]
#  [ 0.11284778 -0.6995611  -0.6287469 ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 5
# inputs ->  [ 0.  0.  0.]
# targets ->  [ 0.  0.  1.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.5]
#  [ 0.5]
#  [ 0.5]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.16349054]
#  [ 0.1613885 ]
#  [ 0.58653624]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.45921816]
#  [ 0.54025978]
#  [ 0.64257001]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.45921816]
#  [-0.54025978]
#  [ 0.35742999]]
# ===========================
# Peso actualizado del output layer:  [[-0.58985072  0.82983432 -0.56696468]
#  [ 1.10275502  0.05189943 -0.83187745]
#  [-0.08000714  0.65173564  0.60134399]]
# Peso actualizado del hidden layer:  [[ 0.6752994  -0.36896126 -0.41544055]
#  [ 0.61857567 -0.48562188 -1.17181246]
#  [ 0.11284778 -0.6995611  -0.6287469 ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 5
# inputs ->  [ 0.  0.  1.]
# targets ->  [ 0.  1.  0.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.41544055]
#  [-1.17181246]
#  [-0.6287469 ]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.3976083 ]
#  [ 0.23652753]
#  [ 0.34779473]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.24103721]
#  [ 0.15482937]
# ...
# [[ 0.39378046]
#  [ 0.33116095]
#  [ 0.25281916]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.01587172]
#  [-0.04272388]
#  [ 0.39601552]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.49603215]
#  [ 0.48932066]
#  [ 0.59772997]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.49603215]
#  [ 0.51067934]
#  [ 0.40227003]]
# ===========================
# Peso actualizado del output layer:  [[-0.5847587   1.2830083  -0.83256118]
#  [ 0.79280115 -0.17987641 -1.16820826]
#  [-0.85568038  1.42269638  1.03561872]]
# Peso actualizado del hidden layer:  [[-0.31711325 -0.42307657  0.67702984]
#  [ 1.87332663 -0.70639346 -3.24270645]
#  [-0.61242115 -1.07923145 -2.35507123]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 98
# inputs ->  [ 0.  1.  1.]
# targets ->  [ 1.  0.  0.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.25395327]
#  [-3.94909991]
#  [-3.43430269]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.5631493 ]
#  [ 0.01890765]
#  [ 0.03124045]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.33398274]
#  [ 0.40957959]
#  [-0.42034085]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.41727188]
#  [ 0.60098707]
#  [ 0.39643519]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.58272812]
#  [-0.60098707]
#  [-0.39643519]]
# ===========================
# Peso actualizado del output layer:  [[-0.58964159  1.2789019  -0.83569614]
#  [ 0.79782625 -0.17565041 -1.164982  ]
#  [-0.85187153  1.42589955  1.03806412]]
# Peso actualizado del hidden layer:  [[-0.31711325 -0.43501731  0.66508909]
#  [ 1.87332663 -0.70586378 -3.24217677]
#  [-0.61242115 -1.07983181 -2.35567159]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 98
# inputs ->  [ 1.  0.  0.]
# targets ->  [ 1.  0.  1.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.31711325]
#  [ 1.87332663]
#  [-0.61242115]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.42137943]
#  [ 0.86684273]
#  [ 0.3515071 ]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[ 0.57014107]
#  [-0.22938752]
#  [ 1.23944584]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.63879572]
#  [ 0.44290326]
#  [ 0.77546754]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.36120428]
#  [-0.44290326]
#  [ 0.22453246]]
# ===========================
# Peso actualizado del output layer:  [[-0.58166211  1.2791698  -0.83525348]
#  [ 0.78971027 -0.1759229  -1.16543223]
#  [-0.85721338  1.42572019  1.03776779]]
# Peso actualizado del hidden layer:  [[-0.33545662 -0.43501731  0.66508909]
#  [ 1.88325421 -0.70586378 -3.24217677]
#  [-0.60222064 -1.07983181 -2.35567159]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 98
# inputs ->  [ 1.  0.  1.]
# targets ->  [ 1.  1.  0.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.32963247]
#  [-1.35892256]
#  [-2.95789223]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.58166995]
#  [ 0.20441547]
#  [ 0.04936483]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.11442123]
#  [ 0.36105341]
#  [-0.15422795]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.47142586]
#  [ 0.58929541]
#  [ 0.46151926]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.52857414]
#  [ 0.41070459]
#  [-0.46151926]]
# ===========================
# Peso actualizado del output layer:  [[-0.57815021  1.28639431 -0.83232393]
#  [ 0.78510536 -0.18539593 -1.16927356]
#  [-0.855566    1.42910912  1.03914201]]
# Peso actualizado del hidden layer:  [[-0.32543845 -0.43501731  0.67510727]
#  [ 1.88234756 -0.70586378 -3.24308342]
#  [-0.6087894  -1.07983181 -2.36224035]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 98
# inputs ->  [ 1.  1.  0.]
# targets ->  [ 1.  1.  1.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.76045576]
#  [ 1.17648377]
#  [-1.68862122]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.31854732]
#  [ 0.76431499]
#  [ 0.15595725]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[ 0.67383502]
#  [-0.07049301]
#  [ 0.9778075 ]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.66236135]
#  [ 0.48238404]
#  [ 0.72667296]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.33763865]
#  [ 0.51761596]
#  [ 0.27332704]]
# ===========================
# Peso actualizado del output layer:  [[-0.57048892  1.28908671 -0.83167373]
#  [ 0.79088723 -0.18336401 -1.16878287]
#  [-0.86223754  1.42676455  1.03857581]]
# Peso actualizado del hidden layer:  [[-0.32584907 -0.43542793  0.67510727]
#  [ 1.89550312 -0.69270821 -3.24308342]
#  [-0.61671269 -1.08775509 -2.36224035]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 98
# inputs ->  [ 1.  1.  1.]
# targets ->  [ 0.  0.  0.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.08616974]
#  [-2.04028851]
#  [-4.06670813]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.47847088]
#  [ 0.11503736]
#  [ 0.01684508]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.1368442 ]
#  [ 0.34077476]
#  [-0.22961042]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.46584224]
#  [ 0.58437871]
#  [ 0.44284827]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.46584224]
#  [-0.58437871]
#  [-0.44284827]]
# ===========================
# Peso actualizado del output layer:  [[-0.5680836   1.29485798 -0.83049611]
#  [ 0.79500425 -0.17348575 -1.16676723]
#  [-0.86050821  1.43091387  1.03942247]]
# Peso actualizado del hidden layer:  [[-0.32132926 -0.43090812  0.67962708]
#  [ 1.88394335 -0.70426799 -3.2546432 ]
#  [-0.61570508 -1.08674749 -2.36123275]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 0.  0.  0.]
# targets ->  [ 0.  0.  1.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.5]
#  [ 0.5]
#  [ 0.5]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.05539839]
#  [-0.27695586]
#  [ 0.80157953]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.48615394]
#  [ 0.43120024]
#  [ 0.69031226]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.48615394]
#  [-0.43120024]
#  [ 0.30968774]]
# ===========================
# Peso actualizado del output layer:  [[-0.5736299   1.2935245  -0.83069138]
#  [ 0.78821312 -0.17511852 -1.16700632]
#  [-0.86573625  1.4296569   1.03923841]]
# Peso actualizado del hidden layer:  [[-0.32132926 -0.43090812  0.67962708]
#  [ 1.88394335 -0.70426799 -3.2546432 ]
#  [-0.61570508 -1.08674749 -2.36123275]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 0.  0.  1.]
# targets ->  [ 0.  1.  0.]
# INPUTS
# [[ 0.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.67962708]
#  [-3.2546432 ]
#  [-2.36123275]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.66365546]
#  [ 0.0371604 ]
#  [ 0.08617707]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.4089901 ]
#  [ 0.4118637 ]
#  [-0.42926029]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.3991543 ]
#  [ 0.60153468]
#  [ 0.39430298]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.3991543 ]
#  [ 0.39846532]
#  [-0.39430298]]
# ===========================
# Peso actualizado del output layer:  [[-0.57970216  1.28745224 -0.83676364]
#  [ 0.78292516 -0.18040647 -1.17229427]
#  [-0.86242598  1.43296718  1.04254868]]
# Peso actualizado del hidden layer:  [[-0.32132926 -0.43090812  0.69934642]
#  [ 1.88394335 -0.70426799 -3.25876071]
#  [-0.61570508 -1.08674749 -2.36551836]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 0.  1.  0.]
# targets ->  [ 0.  1.  1.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.43090812]
#  [-0.70426799]
#  [-1.08674749]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.3939095 ]
#  [ 0.33086664]
#  [ 0.25223124]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.01626146]
#  [-0.04415624]
#  [ 0.39458431]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.49593472]
#  [ 0.48896273]
#  [ 0.59738579]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.49593472]
#  [ 0.51103727]
#  [ 0.40261421]]
# ===========================
# Peso actualizado del output layer:  [[-0.58605528  1.2870965  -0.83758861]
#  [ 0.78926363 -0.18005156 -1.1714712 ]
#  [-0.86867566  1.43261723  1.04173715]]
# Peso actualizado del hidden layer:  [[-0.32132926 -0.4226894   0.69934642]
#  [ 1.88394335 -0.7076672  -3.25876071]
#  [-0.61570508 -1.0822936  -2.36551836]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 0.  1.  1.]
# targets ->  [ 1.  0.  0.]
# INPUTS
# [[ 0.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.27665702]
#  [-3.96642791]
#  [-3.44781196]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.56872646]
#  [ 0.01858888]
#  [ 0.03083418]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.33815587]
#  [ 0.41244541]
#  [-0.43298274]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.41625751]
#  [ 0.6016741 ]
#  [ 0.39341431]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.58374249]
#  [-0.6016741 ]
#  [-0.39341431]]
# ===========================
# Peso actualizado del output layer:  [[-0.59093879  1.28299457 -0.84071566]
#  [ 0.79429374 -0.17582649 -1.16825028]
#  [-0.86486124  1.43582119  1.04417963]]
# Peso actualizado del hidden layer:  [[-0.32132926 -0.43452678  0.68750904]
#  [ 1.88394335 -0.70713841 -3.25823191]
#  [-0.61570508 -1.08288724 -2.366112  ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 1.  0.  0.]
# targets ->  [ 1.  0.  1.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.32132926]
#  [ 1.88394335]
#  [-0.61570508]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.42035183]
#  [ 0.86806341]
#  [ 0.35075889]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[ 0.57420318]
#  [-0.23235581]
#  [ 1.24659565]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.63973247]
#  [ 0.44217099]
#  [ 0.77670999]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.36026753]
#  [-0.44217099]
#  [ 0.22329001]]
# ===========================
# Peso actualizado del output layer:  [[-0.58287187  1.28325824 -0.8402783 ]
#  [ 0.78609278 -0.17609454 -1.16869491]
#  [-0.87020068  1.43564667  1.04389015]]
# Peso actualizado del hidden layer:  [[-0.33964939 -0.43452678  0.68750904]
#  [ 1.89380141 -0.70713841 -3.25823191]
#  [-0.60552276 -1.08288724 -2.366112  ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 1.  0.  1.]
# targets ->  [ 1.  1.  0.]
# INPUTS
# [[ 1.]
#  [ 0.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[ 0.34785966]
#  [-1.3644305 ]
#  [-2.97163476]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.58609846]
#  [ 0.20352117]
#  [ 0.0487239 ]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.11773722]
#  [ 0.36314523]
#  [-0.16527197]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.47059965]
#  [ 0.58980159]
#  [ 0.4587758 ]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.52940035]
#  [ 0.41019841]
#  [-0.4587758 ]]
# ===========================
# Peso actualizado del output layer:  [[-0.57938158  1.29046599 -0.83736586]
#  [ 0.78150826 -0.18556199 -1.17252043]
#  [-0.86857284  1.43900829  1.04524848]]
# Peso actualizado del hidden layer:  [[-0.32964682 -0.43452678  0.69751161]
#  [ 1.89294023 -0.70713841 -3.25909309]
#  [-0.61202937 -1.08288724 -2.3726186 ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 1.  1.  0.]
# targets ->  [ 1.  1.  1.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 0.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.7641736 ]
#  [ 1.18580182]
#  [-1.69491661]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.31774082]
#  [ 0.76598938]
#  [ 0.15513035]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[ 0.67910124]
#  [-0.07224465]
#  [ 0.98445042]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.66353807]
#  [ 0.48194669]
#  [ 0.72799038]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[ 0.33646193]
#  [ 0.51805331]
#  [ 0.27200962]]
# ===========================
# Peso actualizado del output layer:  [[-0.57165138  1.29315028 -0.83672322]
#  [ 0.78732479 -0.18354221 -1.17203688]
#  [-0.87524934  1.43668989  1.04469345]]
# Peso actualizado del hidden layer:  [[-0.33013542 -0.43501538  0.69751161]
#  [ 1.90603988 -0.69403876 -3.25909309]
#  [-0.61995272 -1.09081059 -2.3726186 ]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============
# Iteración # 99
# inputs ->  [ 1.  1.  1.]
# targets ->  [ 0.  0.  0.]
# INPUTS
# [[ 1.]
#  [ 1.]
#  [ 1.]]
# ===========================
# HIDDEN INPUTS (multiplicación cruz de inputs directos con peso wih)
# [[-0.0676392 ]
#  [-2.04709197]
#  [-4.08338192]]
# ===========================
# HIDDEN OUTPUTS (después de aplicar la función sigmoide)
# [[ 0.48309665]
#  [ 0.11434655]
#  [ 0.01657115]]
# ===========================
# FINAL INPUTS (multiplicación cruz de hidden outputs con peso who)
# [[-0.14033077]
#  [ 0.34309613]
#  [-0.23992528]]
# ===========================
# FINAL OUTPUTS (después de aplicar función sigmoide a los final inputs)
# [[ 0.46497477]
#  [ 0.58494241]
#  [ 0.44030476]]
# ===========================
# ERROR (target - valor de los final outputs)
# [[-0.46497477]
#  [-0.58494241]
#  [-0.44030476]]
# ===========================
# Peso actualizado del output layer:  [[-0.56926461  1.29890416 -0.83555793]
#  [ 0.7914346  -0.17363456 -1.17003036]
#  [-0.87353788  1.44081577  1.04552903]]
# Peso actualizado del hidden layer:  [[-0.32548143 -0.43036138  0.70216561]
#  [ 1.89452745 -0.70555119 -3.27060552]
#  [-0.61895446 -1.08981232 -2.37162034]]
# ============= FINAL DE FASE DE ENTRENAMIENTO ==============

# %%
# test the neural network

# scorecard for how well the network performs, initially empty
scorecard = []

# go through all the records in the test data set
for record in test_data_list:
    # split the record by the ',' commas
    all_values = record.split(',')
    # correct answer is first value
    correct_label = int(all_values[0])
    # scale and shift the inputs
    # inputs = (numpy.asfarray(all_values[1:]) / 255.0 * 0.99) + 0.01
    inputs = (numpy.asfarray(all_values[0:3]) / 1.0) + 0.00
    # query the network
    outputs = n.query(inputs)
    print("Outputs -> ", outputs)
    # the index of the highest value corresponds to the label
    label = numpy.argmax(outputs)
    # append correct or incorrect to list
    if (label == correct_label):
        # network's answer matches correct answer, add 1 to scorecard
        scorecard.append(1)
    else:
        # network's answer doesn't match correct answer, add 0 to scorecard
        scorecard.append(0)
        pass
    
    pass
# Out:
# Outputs ->  [[ 0.48587615]
#  [ 0.4303373 ]
#  [ 0.69063127]]
# Outputs ->  [[ 0.39933321]
#  [ 0.60307856]
#  [ 0.39038385]]
# Outputs ->  [[ 0.49803087]
#  [ 0.48918032]
#  [ 0.59693008]]
# Outputs ->  [[ 0.4187785 ]
#  [ 0.60023299]
#  [ 0.39164006]]
# Outputs ->  [[ 0.64436543]
#  [ 0.44202221]
#  [ 0.77708602]]
# Outputs ->  [[ 0.47021545]
#  [ 0.59241776]
#  [ 0.45490246]]
# Outputs ->  [[ 0.66437163]
#  [ 0.48423896]
#  [ 0.72769928]]
# Outputs ->  [[ 0.46264257]
#  [ 0.58488894]
#  [ 0.43767966]]

# %%
# calculate the performance score, the fraction of correct answers
scorecard_array = numpy.asarray(scorecard)
print ("performance = ", scorecard_array.sum() / scorecard_array.size)
# Out:
# performance =  0.125
